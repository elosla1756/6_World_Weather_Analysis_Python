# %%
# Importing the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Creating a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Adding the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Performing an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=483fe0bae00945186b0e4e9928a721ea

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data including weather decription.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp, 
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | gigmoto
# Processing Record 5 of Set 1 | clyde river
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | coahuayana
# Processing Record 8 of Set 1 | snezhnogorsk
# Processing Record 9 of Set 1 | nampula
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | lephepe
# City not found. Skipping...
# Processing Record 12 of Set 1 | dudinka
# Processing Record 13 of Set 1 | bowen
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 1 | talcahuano
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | shushenskoye
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | warwick
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | mount pleasant
# Processing Record 26 of Set 1 | bergen
# Processing Record 27 of Set 1 | vostochnyy
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | magadan
# Processing Record 31 of Set 1 | laela
# Processing Record 32 of Set 1 | marzuq
# Processing Record 33 of Set 1 | ambilobe
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | faya
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | lengshuitan
# Processing Record 39 of Set 1 | labuhan
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | sao filipe
# Processing Record 42 of Set 1 | tautira
# Processing Record 43 of Set 1 | lai
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | ayagoz
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | sitka
# Processing Record 50 of Set 1 | beringovskiy
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | saint-francois
# Processing Record 4 of Set 2 | victoria point
# Processing Record 5 of Set 2 | kahului
# Processing Record 6 of Set 2 | ilulissat
# Processing Record 7 of Set 2 | saint-pierre
# Processing Record 8 of Set 2 | north bend
# Processing Record 9 of Set 2 | batagay-alyta
# Processing Record 10 of Set 2 | yokadouma
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | didao
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | ancud
# Processing Record 16 of Set 2 | berbera
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | okha
# Processing Record 21 of Set 2 | usinsk
# Processing Record 22 of Set 2 | parabel
# Processing Record 23 of Set 2 | korla
# Processing Record 24 of Set 2 | sept-iles
# Processing Record 25 of Set 2 | poya
# Processing Record 26 of Set 2 | linden
# Processing Record 27 of Set 2 | walvis bay
# Processing Record 28 of Set 2 | souillac
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | pavlodar
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | zunyi
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | sawakin
# Processing Record 36 of Set 2 | camacha
# Processing Record 37 of Set 2 | takab
# Processing Record 38 of Set 2 | mandan
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | dickinson
# Processing Record 41 of Set 2 | mount gambier
# Processing Record 42 of Set 2 | la ronge
# Processing Record 43 of Set 2 | morris
# Processing Record 44 of Set 2 | hofn
# Processing Record 45 of Set 2 | fujin
# Processing Record 46 of Set 2 | khorramshahr
# Processing Record 47 of Set 2 | xuddur
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | termini imerese
# Processing Record 1 of Set 3 | baoning
# Processing Record 2 of Set 3 | nome
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | obera
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | hirara
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | phaltan
# Processing Record 9 of Set 3 | safakulevo
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | antananarivo
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | otradnoye
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | sumbe
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | esfahan
# Processing Record 21 of Set 3 | chilca
# Processing Record 22 of Set 3 | ust-nera
# Processing Record 23 of Set 3 | saint pete beach
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | cap malheureux
# Processing Record 26 of Set 3 | rawson
# Processing Record 27 of Set 3 | barrow
# Processing Record 28 of Set 3 | chinna salem
# Processing Record 29 of Set 3 | aswan
# Processing Record 30 of Set 3 | catuday
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | toccoa
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | vysokogornyy
# Processing Record 37 of Set 3 | prnjavor
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | scarborough
# Processing Record 40 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 3 | beruni
# City not found. Skipping...
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | shingu
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | pontes e lacerda
# Processing Record 48 of Set 3 | iralaya
# Processing Record 49 of Set 3 | auki
# Processing Record 50 of Set 3 | sistranda
# Processing Record 1 of Set 4 | namatanai
# Processing Record 2 of Set 4 | arman
# Processing Record 3 of Set 4 | padang
# Processing Record 4 of Set 4 | litovko
# Processing Record 5 of Set 4 | westlock
# Processing Record 6 of Set 4 | gat
# Processing Record 7 of Set 4 | kaeo
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | baykit
# Processing Record 11 of Set 4 | yurginskoye
# Processing Record 12 of Set 4 | robertsport
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | burnham
# Processing Record 16 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 4 | ningan
# City not found. Skipping...
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | pavlogradka
# Processing Record 20 of Set 4 | krasnozerskoye
# Processing Record 21 of Set 4 | solvychegodsk
# Processing Record 22 of Set 4 | kalengwa
# Processing Record 23 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 4 | cabedelo
# Processing Record 25 of Set 4 | bilibino
# Processing Record 26 of Set 4 | bengkulu
# Processing Record 27 of Set 4 | cabo san lucas
# Processing Record 28 of Set 4 | santa rita
# Processing Record 29 of Set 4 | erenhot
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | fairbanks
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | ballina
# Processing Record 34 of Set 4 | rio gallegos
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 4 | yarega
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | asau
# Processing Record 39 of Set 4 | kavaratti
# Processing Record 40 of Set 4 | mexico
# Processing Record 41 of Set 4 | compiegne
# Processing Record 42 of Set 4 | villa maria
# Processing Record 43 of Set 4 | zeven
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | jumla
# Processing Record 46 of Set 4 | terra nova
# Processing Record 47 of Set 4 | vaini
# Processing Record 48 of Set 4 | nabire
# Processing Record 49 of Set 4 | marawi
# Processing Record 50 of Set 4 | neiafu
# Processing Record 1 of Set 5 | taraza
# Processing Record 2 of Set 5 | penzance
# Processing Record 3 of Set 5 | chumikan
# Processing Record 4 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | smidovich
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | maceio
# Processing Record 9 of Set 5 | port lincoln
# Processing Record 10 of Set 5 | sinnamary
# Processing Record 11 of Set 5 | devonport
# Processing Record 12 of Set 5 | port augusta
# Processing Record 13 of Set 5 | vardo
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | urengoy
# Processing Record 16 of Set 5 | kaka
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | khandyga
# Processing Record 20 of Set 5 | luanda
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | balkanabat
# Processing Record 23 of Set 5 | czersk
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | changping
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | solwezi
# Processing Record 28 of Set 5 | bloomingdale
# Processing Record 29 of Set 5 | beira
# Processing Record 30 of Set 5 | mkushi
# Processing Record 31 of Set 5 | harlingen
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | paragould
# Processing Record 34 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | mana
# Processing Record 37 of Set 5 | malakal
# Processing Record 38 of Set 5 | kilindoni
# Processing Record 39 of Set 5 | salmas
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 5 | bandarbeyla
# Processing Record 43 of Set 5 | kjollefjord
# Processing Record 44 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 5 | tungor
# Processing Record 46 of Set 5 | necochea
# Processing Record 47 of Set 5 | neustadt
# Processing Record 48 of Set 5 | sambava
# Processing Record 49 of Set 5 | chokurdakh
# Processing Record 50 of Set 5 | miraflores
# Processing Record 1 of Set 6 | fallon
# Processing Record 2 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 6 | port hardy
# Processing Record 4 of Set 6 | kuli
# Processing Record 5 of Set 6 | ajdabiya
# Processing Record 6 of Set 6 | balsta
# Processing Record 7 of Set 6 | itarema
# Processing Record 8 of Set 6 | maryborough
# Processing Record 9 of Set 6 | ormara
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | hami
# Processing Record 12 of Set 6 | tashla
# Processing Record 13 of Set 6 | palmer
# Processing Record 14 of Set 6 | xai-xai
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | kottapalli
# Processing Record 18 of Set 6 | santo tomas
# Processing Record 19 of Set 6 | tomatlan
# Processing Record 20 of Set 6 | mangan
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | pulivendla
# Processing Record 23 of Set 6 | ulagan
# Processing Record 24 of Set 6 | sisimiut
# Processing Record 25 of Set 6 | beroroha
# Processing Record 26 of Set 6 | santa luzia
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | timberlake
# Processing Record 29 of Set 6 | prince rupert
# Processing Record 30 of Set 6 | naze
# Processing Record 31 of Set 6 | mogadishu
# Processing Record 32 of Set 6 | rabo de peixe
# Processing Record 33 of Set 6 | grand-santi
# Processing Record 34 of Set 6 | butaritari
# Processing Record 35 of Set 6 | helong
# Processing Record 36 of Set 6 | llanes
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | tashtyp
# Processing Record 39 of Set 6 | laguna
# Processing Record 40 of Set 6 | karratha
# Processing Record 41 of Set 6 | strezhevoy
# Processing Record 42 of Set 6 | pundaguitan
# Processing Record 43 of Set 6 | mandiana
# Processing Record 44 of Set 6 | rabat
# Processing Record 45 of Set 6 | price
# Processing Record 46 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 6 | cap-aux-meules
# Processing Record 48 of Set 6 | severo-kurilsk
# Processing Record 49 of Set 6 | bosaso
# Processing Record 50 of Set 6 | constitucion
# Processing Record 1 of Set 7 | sarangani
# Processing Record 2 of Set 7 | belaya gora
# Processing Record 3 of Set 7 | allanmyo
# City not found. Skipping...
# Processing Record 4 of Set 7 | puerto escondido
# Processing Record 5 of Set 7 | puerto madero
# Processing Record 6 of Set 7 | ondangwa
# Processing Record 7 of Set 7 | hithadhoo
# Processing Record 8 of Set 7 | moussoro
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | polovinnoye
# Processing Record 11 of Set 7 | batangafo
# Processing Record 12 of Set 7 | raymond
# Processing Record 13 of Set 7 | mount isa
# Processing Record 14 of Set 7 | chernyshevskiy
# Processing Record 15 of Set 7 | marsa matruh
# Processing Record 16 of Set 7 | canchungo
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | tecoanapa
# Processing Record 19 of Set 7 | lata
# Processing Record 20 of Set 7 | vyritsa
# Processing Record 21 of Set 7 | kota bahru
# Processing Record 22 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 7 | wellington
# Processing Record 24 of Set 7 | alta floresta
# Processing Record 25 of Set 7 | hervey bay
# Processing Record 26 of Set 7 | toora-khem
# Processing Record 27 of Set 7 | whitianga
# Processing Record 28 of Set 7 | mezhdurechenskiy
# Processing Record 29 of Set 7 | saint-augustin
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | mezen
# Processing Record 32 of Set 7 | kenai
# Processing Record 33 of Set 7 | adre
# Processing Record 34 of Set 7 | rio grande
# Processing Record 35 of Set 7 | broken hill
# Processing Record 36 of Set 7 | barranca
# Processing Record 37 of Set 7 | saint-leu
# Processing Record 38 of Set 7 | alice springs
# Processing Record 39 of Set 7 | fare
# Processing Record 40 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 7 | ketchikan
# Processing Record 42 of Set 7 | buesaco
# Processing Record 43 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 7 | erzurum
# Processing Record 45 of Set 7 | uray
# Processing Record 46 of Set 7 | daru
# Processing Record 47 of Set 7 | viksoyri
# City not found. Skipping...
# Processing Record 48 of Set 7 | hobyo
# Processing Record 49 of Set 7 | ugoofaaru
# Processing Record 50 of Set 7 | georgetown
# Processing Record 1 of Set 8 | bose
# Processing Record 2 of Set 8 | huadian
# Processing Record 3 of Set 8 | lorengau
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | fuente palmera
# Processing Record 6 of Set 8 | meulaboh
# Processing Record 7 of Set 8 | bridlington
# Processing Record 8 of Set 8 | kralendijk
# Processing Record 9 of Set 8 | saint george
# Processing Record 10 of Set 8 | hare bay
# Processing Record 11 of Set 8 | valley city
# Processing Record 12 of Set 8 | malibu
# Processing Record 13 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 8 | lincoln
# Processing Record 15 of Set 8 | bella union
# Processing Record 16 of Set 8 | presque isle
# Processing Record 17 of Set 8 | ampanihy
# Processing Record 18 of Set 8 | miramar
# Processing Record 19 of Set 8 | herat
# Processing Record 20 of Set 8 | zhanakorgan
# Processing Record 21 of Set 8 | christchurch
# Processing Record 22 of Set 8 | dukat
# Processing Record 23 of Set 8 | opuwo
# Processing Record 24 of Set 8 | tamandare
# Processing Record 25 of Set 8 | akyab
# Processing Record 26 of Set 8 | luzon
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | bereda
# Processing Record 29 of Set 8 | mercedes
# Processing Record 30 of Set 8 | pouembout
# Processing Record 31 of Set 8 | gravdal
# Processing Record 32 of Set 8 | tucuman
# Processing Record 33 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 8 | kavieng
# Processing Record 35 of Set 8 | yelizovo
# Processing Record 36 of Set 8 | naryan-mar
# Processing Record 37 of Set 8 | mackenzie
# Processing Record 38 of Set 8 | verkhoyansk
# Processing Record 39 of Set 8 | isangel
# Processing Record 40 of Set 8 | saint-georges
# Processing Record 41 of Set 8 | kudahuvadhoo
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | alofi
# Processing Record 44 of Set 8 | anadyr
# Processing Record 45 of Set 8 | bambous virieux
# Processing Record 46 of Set 8 | qaqortoq
# Processing Record 47 of Set 8 | sauda
# Processing Record 48 of Set 8 | ostersund
# Processing Record 49 of Set 8 | brae
# Processing Record 50 of Set 8 | simi
# Processing Record 1 of Set 9 | copiapo
# Processing Record 2 of Set 9 | uruzgan
# Processing Record 3 of Set 9 | tuatapere
# Processing Record 4 of Set 9 | port-gentil
# Processing Record 5 of Set 9 | peniche
# Processing Record 6 of Set 9 | darnah
# Processing Record 7 of Set 9 | utinga
# Processing Record 8 of Set 9 | las lomas
# Processing Record 9 of Set 9 | zarubino
# Processing Record 10 of Set 9 | leshukonskoye
# Processing Record 11 of Set 9 | tiarei
# Processing Record 12 of Set 9 | ponta do sol
# Processing Record 13 of Set 9 | udachnyy
# Processing Record 14 of Set 9 | coquimbo
# Processing Record 15 of Set 9 | harnosand
# Processing Record 16 of Set 9 | iracoubo
# Processing Record 17 of Set 9 | nerchinskiy zavod
# Processing Record 18 of Set 9 | arraial do cabo
# Processing Record 19 of Set 9 | virginia beach
# Processing Record 20 of Set 9 | kroya
# Processing Record 21 of Set 9 | honningsvag
# Processing Record 22 of Set 9 | ponta delgada
# Processing Record 23 of Set 9 | chara
# Processing Record 24 of Set 9 | luganville
# Processing Record 25 of Set 9 | tucumcari
# Processing Record 26 of Set 9 | matamoros
# Processing Record 27 of Set 9 | sibolga
# Processing Record 28 of Set 9 | ibra
# Processing Record 29 of Set 9 | roald
# Processing Record 30 of Set 9 | vila franca do campo
# Processing Record 31 of Set 9 | soyo
# Processing Record 32 of Set 9 | kon tum
# Processing Record 33 of Set 9 | shipitsyno
# Processing Record 34 of Set 9 | batetskiy
# Processing Record 35 of Set 9 | pangnirtung
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | san cristobal
# Processing Record 38 of Set 9 | jizan
# Processing Record 39 of Set 9 | taksimo
# Processing Record 40 of Set 9 | tottori
# Processing Record 41 of Set 9 | juegang
# Processing Record 42 of Set 9 | mehamn
# Processing Record 43 of Set 9 | wukari
# Processing Record 44 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 45 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 9 | college
# Processing Record 47 of Set 9 | balkhash
# Processing Record 48 of Set 9 | sorong
# Processing Record 49 of Set 9 | pokrovsk
# Processing Record 50 of Set 9 | acari
# Processing Record 1 of Set 10 | yuancheng
# Processing Record 2 of Set 10 | plettenberg bay
# Processing Record 3 of Set 10 | rogatica
# Processing Record 4 of Set 10 | inca
# Processing Record 5 of Set 10 | bubaque
# Processing Record 6 of Set 10 | praia da vitoria
# Processing Record 7 of Set 10 | codrington
# Processing Record 8 of Set 10 | tual
# Processing Record 9 of Set 10 | keuruu
# Processing Record 10 of Set 10 | helena
# Processing Record 11 of Set 10 | zmiyiv
# Processing Record 12 of Set 10 | eyl
# Processing Record 13 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 10 | flinders
# Processing Record 15 of Set 10 | mangai
# Processing Record 16 of Set 10 | cassilandia
# Processing Record 17 of Set 10 | svetlogorsk
# Processing Record 18 of Set 10 | mora
# Processing Record 19 of Set 10 | pincher creek
# Processing Record 20 of Set 10 | la asuncion
# Processing Record 21 of Set 10 | coruripe
# Processing Record 22 of Set 10 | viedma
# Processing Record 23 of Set 10 | krasnyy chikoy
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | skibbereen
# Processing Record 26 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 10 | villagarzon
# Processing Record 28 of Set 10 | ouallam
# Processing Record 29 of Set 10 | makinsk
# Processing Record 30 of Set 10 | darhan
# Processing Record 31 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 10 | bandar-e lengeh
# Processing Record 33 of Set 10 | nishihara
# Processing Record 34 of Set 10 | tandalti
# Processing Record 35 of Set 10 | bereznik
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | oskemen
# Processing Record 38 of Set 10 | nouadhibou
# Processing Record 39 of Set 10 | chake chake
# Processing Record 40 of Set 10 | katsuura
# Processing Record 41 of Set 10 | shimoda
# Processing Record 42 of Set 10 | khowst
# Processing Record 43 of Set 10 | lucea
# Processing Record 44 of Set 10 | bayan
# Processing Record 45 of Set 10 | morondava
# Processing Record 46 of Set 10 | terney
# Processing Record 47 of Set 10 | grand gaube
# Processing Record 48 of Set 10 | axim
# Processing Record 49 of Set 10 | sarakhs
# Processing Record 50 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | taoudenni
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | klaksvik
# Processing Record 6 of Set 11 | langsa
# Processing Record 7 of Set 11 | hohhot
# Processing Record 8 of Set 11 | san pedro
# Processing Record 9 of Set 11 | atasu
# Processing Record 10 of Set 11 | wuda
# Processing Record 11 of Set 11 | kodinsk
# Processing Record 12 of Set 11 | elban
# Processing Record 13 of Set 11 | comodoro rivadavia
# Processing Record 14 of Set 11 | dalaba
# Processing Record 15 of Set 11 | epinal
# Processing Record 16 of Set 11 | tala
# Processing Record 17 of Set 11 | saldanha
# Processing Record 18 of Set 11 | cache creek
# Processing Record 19 of Set 11 | joshimath
# Processing Record 20 of Set 11 | high level
# Processing Record 21 of Set 11 | novoasbest
# Processing Record 22 of Set 11 | caravelas
# Processing Record 23 of Set 11 | bykov
# Processing Record 24 of Set 11 | bundaberg
# Processing Record 25 of Set 11 | nyurba
# Processing Record 26 of Set 11 | susanino
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | satu mare
# Processing Record 29 of Set 11 | olbia
# Processing Record 30 of Set 11 | olafsvik
# Processing Record 31 of Set 11 | bo
# City not found. Skipping...
# Processing Record 32 of Set 11 | mahanje
# Processing Record 33 of Set 11 | dali
# Processing Record 34 of Set 11 | molchanovo
# Processing Record 35 of Set 11 | aklavik
# Processing Record 36 of Set 11 | komsomolskiy
# Processing Record 37 of Set 11 | kuytun
# Processing Record 38 of Set 11 | teahupoo
# Processing Record 39 of Set 11 | iskateley
# Processing Record 40 of Set 11 | solnechnyy
# Processing Record 41 of Set 11 | ocos
# Processing Record 42 of Set 11 | manzhouli
# Processing Record 43 of Set 11 | inhambane
# Processing Record 44 of Set 11 | kerema
# Processing Record 45 of Set 11 | arlit
# Processing Record 46 of Set 11 | turbat
# Processing Record 47 of Set 11 | hanmer springs
# Processing Record 48 of Set 11 | waipawa
# Processing Record 49 of Set 11 | baculin
# Processing Record 50 of Set 11 | redmond
# Processing Record 1 of Set 12 | lebanon
# Processing Record 2 of Set 12 | san felipe
# Processing Record 3 of Set 12 | te anau
# Processing Record 4 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 12 | nalut
# Processing Record 6 of Set 12 | muros
# Processing Record 7 of Set 12 | port hedland
# Processing Record 8 of Set 12 | amapa
# Processing Record 9 of Set 12 | liverpool
# Processing Record 10 of Set 12 | sulangan
# Processing Record 11 of Set 12 | dunedin
# Processing Record 12 of Set 12 | ucluelet
# Processing Record 13 of Set 12 | kutum
# Processing Record 14 of Set 12 | novopavlovka
# Processing Record 15 of Set 12 | sri aman
# Processing Record 16 of Set 12 | pochutla
# Processing Record 17 of Set 12 | kargasok
# Processing Record 18 of Set 12 | oga
# Processing Record 19 of Set 12 | chicama
# Processing Record 20 of Set 12 | korsor
# Processing Record 21 of Set 12 | luderitz
# Processing Record 22 of Set 12 | hovd
# Processing Record 23 of Set 12 | villacarrillo
# Processing Record 24 of Set 12 | mayor pablo lagerenza
# Processing Record 25 of Set 12 | dabola
# Processing Record 26 of Set 12 | hamilton
# Processing Record 27 of Set 12 | omboue
# Processing Record 28 of Set 12 | shetpe
# Processing Record 29 of Set 12 | kruisfontein
# Processing Record 30 of Set 12 | yanji
# Processing Record 31 of Set 12 | imbituba
# Processing Record 32 of Set 12 | nikolayevsk-na-amure
# Processing Record 33 of Set 12 | vredendal
# Processing Record 34 of Set 12 | waingapu
# Processing Record 35 of Set 12 | la macarena
# Processing Record 36 of Set 12 | sant feliu de guixols
# Processing Record 37 of Set 12 | san policarpo
# Processing Record 38 of Set 12 | killybegs
# Processing Record 39 of Set 12 | birao
# Processing Record 40 of Set 12 | capaci
# Processing Record 41 of Set 12 | patacamaya
# Processing Record 42 of Set 12 | marica
# Processing Record 43 of Set 12 | port hawkesbury
# Processing Record 44 of Set 12 | sampit
# Processing Record 45 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 47 of Set 12 | dinar
# Processing Record 48 of Set 12 | guangyuan
# Processing Record 49 of Set 12 | yar-sale
# Processing Record 50 of Set 12 | srednekolymsk
# Processing Record 1 of Set 13 | avera
# Processing Record 2 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 13 | amahai
# Processing Record 4 of Set 13 | mahibadhoo
# Processing Record 5 of Set 13 | celestun
# Processing Record 6 of Set 13 | sawtell
# Processing Record 7 of Set 13 | bonthe
# Processing Record 8 of Set 13 | tome
# Processing Record 9 of Set 13 | eureka
# Processing Record 10 of Set 13 | haapiti
# Processing Record 11 of Set 13 | abu kamal
# Processing Record 12 of Set 13 | mbanza-ngungu
# Processing Record 13 of Set 13 | thinadhoo
# Processing Record 14 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 13 | san quintin
# Processing Record 16 of Set 13 | urdoma
# Processing Record 17 of Set 13 | nelson bay
# Processing Record 18 of Set 13 | fredericksburg
# Processing Record 19 of Set 13 | tamiahua
# Processing Record 20 of Set 13 | pangoa
# Processing Record 21 of Set 13 | raga
# Processing Record 22 of Set 13 | fort nelson
# Processing Record 23 of Set 13 | vila velha
# Processing Record 24 of Set 13 | chardara
# Processing Record 25 of Set 13 | yuanping
# Processing Record 26 of Set 13 | samarai
# Processing Record 27 of Set 13 | matamba
# Processing Record 28 of Set 13 | ostrovnoy
# Processing Record 29 of Set 13 | surt
# Processing Record 30 of Set 13 | sitrah
# Processing Record 31 of Set 13 | westport
# Processing Record 32 of Set 13 | bam
# Processing Record 33 of Set 13 | aldan
# Processing Record 34 of Set 13 | adrar
# Processing Record 35 of Set 13 | antofagasta
# Processing Record 36 of Set 13 | hamina
# Processing Record 37 of Set 13 | emba
# Processing Record 38 of Set 13 | dicabisagan
# Processing Record 39 of Set 13 | stirion
# Processing Record 40 of Set 13 | northam
# Processing Record 41 of Set 13 | bhanjanagar
# Processing Record 42 of Set 13 | atambua
# Processing Record 43 of Set 13 | benjamin constant
# Processing Record 44 of Set 13 | ahipara
# Processing Record 45 of Set 13 | haines junction
# Processing Record 46 of Set 13 | paamiut
# Processing Record 47 of Set 13 | gorodovikovsk
# Processing Record 48 of Set 13 | mahina
# Processing Record 49 of Set 13 | shiyan
# Processing Record 50 of Set 13 | sao joao da barra
# Processing Record 1 of Set 14 | calvinia
# Processing Record 2 of Set 14 | kulachi
# Processing Record 3 of Set 14 | camargo
# Processing Record 4 of Set 14 | rio tinto
# Processing Record 5 of Set 14 | teresina
# Processing Record 6 of Set 14 | kishapu
# Processing Record 7 of Set 14 | steamboat springs
# Processing Record 8 of Set 14 | takoradi
# Processing Record 9 of Set 14 | rumoi
# Processing Record 10 of Set 14 | blythe
# Processing Record 11 of Set 14 | sechura
# Processing Record 12 of Set 14 | leh
# Processing Record 13 of Set 14 | margate
# Processing Record 14 of Set 14 | half moon bay
# Processing Record 15 of Set 14 | micheweni
# Processing Record 16 of Set 14 | goure
# Processing Record 17 of Set 14 | tarakan
# Processing Record 18 of Set 14 | bom jesus
# Processing Record 19 of Set 14 | maragogi
# Processing Record 20 of Set 14 | mandalgovi
# Processing Record 21 of Set 14 | usak
# Processing Record 22 of Set 14 | senmonorom
# City not found. Skipping...
# Processing Record 23 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 14 | itaituba
# Processing Record 25 of Set 14 | aykhal
# Processing Record 26 of Set 14 | pacifica
# Processing Record 27 of Set 14 | hokitika
# Processing Record 28 of Set 14 | spornoye
# Processing Record 29 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 14 | mandal
# Processing Record 31 of Set 14 | chunoyar
# Processing Record 32 of Set 14 | jijiang
# Processing Record 33 of Set 14 | khatassy
# Processing Record 34 of Set 14 | altamira
# Processing Record 35 of Set 14 | lanja
# Processing Record 36 of Set 14 | cananea
# Processing Record 37 of Set 14 | beloha
# Processing Record 38 of Set 14 | ayan
# Processing Record 39 of Set 14 | otacilio costa
# Processing Record 40 of Set 14 | khromtau
# Processing Record 41 of Set 14 | swift current
# Processing Record 42 of Set 14 | rocha
# Processing Record 43 of Set 14 | rosario
# Processing Record 44 of Set 14 | rafaela
# Processing Record 45 of Set 14 | touho
# Processing Record 46 of Set 14 | oriximina
# Processing Record 47 of Set 14 | pemangkat
# Processing Record 48 of Set 14 | alyangula
# Processing Record 49 of Set 14 | kawalu
# Processing Record 50 of Set 14 | nosy varika
# Processing Record 1 of Set 15 | lima
# Processing Record 2 of Set 15 | raudeberg
# Processing Record 3 of Set 15 | kamenka
# Processing Record 4 of Set 15 | mikhaylovka
# Processing Record 5 of Set 15 | luena
# Processing Record 6 of Set 15 | dhing
# Processing Record 7 of Set 15 | puerto cabezas
# Processing Record 8 of Set 15 | daimiel
# Processing Record 9 of Set 15 | pimenteiras
# Processing Record 10 of Set 15 | kaya
# Processing Record 11 of Set 15 | chipinge
# Processing Record 12 of Set 15 | harper
# Processing Record 13 of Set 15 | collie
# Processing Record 14 of Set 15 | menongue
# Processing Record 15 of Set 15 | altamirano
# Processing Record 16 of Set 15 | pabianice
# Processing Record 17 of Set 15 | lasa
# Processing Record 18 of Set 15 | san juan
# Processing Record 19 of Set 15 | krasnoselkup
# Processing Record 20 of Set 15 | yarada
# Processing Record 21 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 15 | buala
# Processing Record 23 of Set 15 | cairns
# Processing Record 24 of Set 15 | pakpattan
# Processing Record 25 of Set 15 | isla mujeres
# Processing Record 26 of Set 15 | the pas
# Processing Record 27 of Set 15 | balmedie
# Processing Record 28 of Set 15 | djibo
# Processing Record 29 of Set 15 | ust-ishim
# Processing Record 30 of Set 15 | puerto rico
# Processing Record 31 of Set 15 | urusha
# Processing Record 32 of Set 15 | berlevag
# Processing Record 33 of Set 15 | nieuw amsterdam
# Processing Record 34 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 15 | gumushane
# City not found. Skipping...
# Processing Record 37 of Set 15 | buraydah
# Processing Record 38 of Set 15 | spassk
# Processing Record 39 of Set 15 | kaohsiung
# Processing Record 40 of Set 15 | medicine hat
# Processing Record 41 of Set 15 | oytal
# Processing Record 42 of Set 15 | wakuya
# Processing Record 43 of Set 15 | qingdao
# Processing Record 44 of Set 15 | mangrol
# Processing Record 45 of Set 15 | bismil
# Processing Record 46 of Set 15 | nizhniy baskunchak
# Processing Record 47 of Set 15 | homer
# Processing Record 48 of Set 15 | sierpc
# Processing Record 49 of Set 15 | richards bay
# Processing Record 50 of Set 15 | el cobre
# Processing Record 1 of Set 16 | pawtucket
# Processing Record 2 of Set 16 | skelleftea
# Processing Record 3 of Set 16 | aginskoye
# Processing Record 4 of Set 16 | gamba
# Processing Record 5 of Set 16 | ust-maya
# Processing Record 6 of Set 16 | vaitape
# Processing Record 7 of Set 16 | yilan
# Processing Record 8 of Set 16 | yumen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      RE -21.3585   55.7679     71.19        80          36
# 1         Ushuaia      AR -54.8000  -68.3000     26.42        93          99
# 2        Khatanga      RU  71.9667  102.5000     29.68        85          97
# 3         Gigmoto      PH  13.7796  124.3900     84.99        78          93
# 4     Clyde River      CA  70.4692  -68.5914     28.63        86          90
#
#    Wind Speed Current Description
# 0        4.36    scattered clouds
# 1        4.05          light snow
# 2       10.25     overcast clouds
# 3        8.46     overcast clouds
# 4       21.85     overcast clouds

# %%
# Creating the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Exporting the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
