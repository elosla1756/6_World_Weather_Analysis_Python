# %%
# Importing the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Creating a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Adding the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Performing an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=483fe0bae00945186b0e4e9928a721ea

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data including weather decription.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp, 
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | gwadar
# Processing Record 10 of Set 1 | thinadhoo
# Processing Record 11 of Set 1 | tual
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | volot
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | bara
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | sinnamary
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | mananjary
# Processing Record 24 of Set 1 | paamiut
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | gat
# Processing Record 28 of Set 1 | jackson
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | balkanabat
# Processing Record 31 of Set 1 | korla
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | ilhabela
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | lotofaga
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | kieta
# Processing Record 41 of Set 1 | malard
# Processing Record 42 of Set 1 | ontario
# Processing Record 43 of Set 1 | solnechnyy
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | iquitos
# Processing Record 48 of Set 1 | bulancak
# Processing Record 49 of Set 1 | polson
# Processing Record 50 of Set 1 | patos de minas
# Processing Record 1 of Set 2 | rio grande
# Processing Record 2 of Set 2 | iskateley
# Processing Record 3 of Set 2 | manyana
# Processing Record 4 of Set 2 | coquimbo
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | sudogda
# Processing Record 8 of Set 2 | zhezkazgan
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | piran
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | magadan
# Processing Record 13 of Set 2 | kongoussi
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | marawi
# Processing Record 16 of Set 2 | zhigansk
# Processing Record 17 of Set 2 | moerai
# Processing Record 18 of Set 2 | havelock
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | trairi
# Processing Record 21 of Set 2 | geraldton
# Processing Record 22 of Set 2 | olga
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | wukari
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | bowen
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | wangqing
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | tall kayf
# Processing Record 37 of Set 2 | half moon bay
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | ejido
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | sembe
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | cape coast
# Processing Record 46 of Set 2 | great yarmouth
# Processing Record 47 of Set 2 | hualmay
# Processing Record 48 of Set 2 | upington
# Processing Record 49 of Set 2 | gabriel leyva solano
# Processing Record 50 of Set 2 | vao
# Processing Record 1 of Set 3 | mandan
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | nishihara
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | meulaboh
# Processing Record 6 of Set 3 | hirtshals
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | gap
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | aguimes
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | narsaq
# Processing Record 13 of Set 3 | bentong
# Processing Record 14 of Set 3 | diffa
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | kruisfontein
# Processing Record 17 of Set 3 | yerbogachen
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | wasilla
# Processing Record 20 of Set 3 | kovdor
# Processing Record 21 of Set 3 | san patricio
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | takoradi
# Processing Record 26 of Set 3 | harper
# Processing Record 27 of Set 3 | bambous virieux
# Processing Record 28 of Set 3 | linxia
# Processing Record 29 of Set 3 | walla walla
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 35 of Set 3 | anadyr
# Processing Record 36 of Set 3 | jaque
# Processing Record 37 of Set 3 | cockburn town
# Processing Record 38 of Set 3 | pucara
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | esna
# Processing Record 45 of Set 3 | quibdo
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | gisborne
# Processing Record 48 of Set 3 | kavieng
# Processing Record 49 of Set 3 | lompoc
# Processing Record 50 of Set 3 | puerto carreno
# Processing Record 1 of Set 4 | zalantun
# Processing Record 2 of Set 4 | kavaratti
# Processing Record 3 of Set 4 | goderich
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | lusambo
# Processing Record 6 of Set 4 | alekseyevsk
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | belinskiy
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | asuncion
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | waipawa
# Processing Record 14 of Set 4 | bethel
# Processing Record 15 of Set 4 | bom jesus
# Processing Record 16 of Set 4 | saint-georges
# Processing Record 17 of Set 4 | adamovka
# Processing Record 18 of Set 4 | feicheng
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | puerto escondido
# Processing Record 22 of Set 4 | husavik
# Processing Record 23 of Set 4 | xam nua
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | sortland
# Processing Record 27 of Set 4 | akcakoca
# Processing Record 28 of Set 4 | kaitangata
# Processing Record 29 of Set 4 | mosquera
# Processing Record 30 of Set 4 | bismarck
# Processing Record 31 of Set 4 | pacific grove
# Processing Record 32 of Set 4 | kungsbacka
# Processing Record 33 of Set 4 | cairns
# Processing Record 34 of Set 4 | bull savanna
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | sarakhs
# Processing Record 37 of Set 4 | boueni
# Processing Record 38 of Set 4 | tabou
# Processing Record 39 of Set 4 | cururupu
# Processing Record 40 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 4 | zonguldak
# Processing Record 42 of Set 4 | mabay
# Processing Record 43 of Set 4 | batagay
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | gao
# Processing Record 46 of Set 4 | komsomolskiy
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | safaga
# Processing Record 49 of Set 4 | livingston
# Processing Record 50 of Set 4 | sao sebastiao
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | samarai
# Processing Record 3 of Set 5 | syumsi
# Processing Record 4 of Set 5 | petawawa
# Processing Record 5 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 5 | merauke
# Processing Record 7 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 5 | los llanos de aridane
# Processing Record 9 of Set 5 | san andres
# Processing Record 10 of Set 5 | broome
# Processing Record 11 of Set 5 | mackay
# Processing Record 12 of Set 5 | mabamba
# Processing Record 13 of Set 5 | gadarwara
# Processing Record 14 of Set 5 | arraial do cabo
# Processing Record 15 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 16 of Set 5 | katima mulilo
# Processing Record 17 of Set 5 | khani
# Processing Record 18 of Set 5 | hilo
# Processing Record 19 of Set 5 | riviere-au-renard
# Processing Record 20 of Set 5 | soyo
# Processing Record 21 of Set 5 | ati
# Processing Record 22 of Set 5 | akureyri
# Processing Record 23 of Set 5 | barcarena
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | margate
# Processing Record 26 of Set 5 | catuday
# Processing Record 27 of Set 5 | okhotsk
# Processing Record 28 of Set 5 | izhevsk
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | porbandar
# Processing Record 31 of Set 5 | umba
# Processing Record 32 of Set 5 | kamakura
# Processing Record 33 of Set 5 | ariquemes
# Processing Record 34 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 5 | beyneu
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | dieppe
# Processing Record 38 of Set 5 | puerto del rosario
# Processing Record 39 of Set 5 | sulangan
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | yatou
# Processing Record 42 of Set 5 | patea
# Processing Record 43 of Set 5 | aasiaat
# Processing Record 44 of Set 5 | eureka
# Processing Record 45 of Set 5 | flinders
# Processing Record 46 of Set 5 | hambantota
# Processing Record 47 of Set 5 | tvoroyri
# Processing Record 48 of Set 5 | chokurdakh
# Processing Record 49 of Set 5 | golyshmanovo
# Processing Record 50 of Set 5 | ornskoldsvik
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | broken hill
# Processing Record 5 of Set 6 | luganville
# Processing Record 6 of Set 6 | college
# Processing Record 7 of Set 6 | umm lajj
# Processing Record 8 of Set 6 | corner brook
# Processing Record 9 of Set 6 | mizdah
# Processing Record 10 of Set 6 | sao joao da barra
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | malanje
# Processing Record 13 of Set 6 | aklavik
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | vredendal
# Processing Record 16 of Set 6 | nadym
# Processing Record 17 of Set 6 | oussouye
# Processing Record 18 of Set 6 | vestmannaeyjar
# Processing Record 19 of Set 6 | malindi
# Processing Record 20 of Set 6 | necochea
# Processing Record 21 of Set 6 | beauceville
# Processing Record 22 of Set 6 | te anau
# Processing Record 23 of Set 6 | salalah
# Processing Record 24 of Set 6 | corralillo
# Processing Record 25 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | bhan
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | kunashak
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | yenotayevka
# Processing Record 32 of Set 6 | vila franca do campo
# Processing Record 33 of Set 6 | esperance
# Processing Record 34 of Set 6 | boyolangu
# Processing Record 35 of Set 6 | naron
# Processing Record 36 of Set 6 | miles city
# Processing Record 37 of Set 6 | bandarbeyla
# Processing Record 38 of Set 6 | republic
# Processing Record 39 of Set 6 | maldonado
# Processing Record 40 of Set 6 | bozdar
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 6 | huilong
# Processing Record 44 of Set 6 | krasnoselkup
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | bonthe
# Processing Record 47 of Set 6 | oksfjord
# Processing Record 48 of Set 6 | rio cuarto
# Processing Record 49 of Set 6 | ahuimanu
# Processing Record 50 of Set 6 | jasper
# Processing Record 1 of Set 7 | pangnirtung
# Processing Record 2 of Set 7 | kaka
# Processing Record 3 of Set 7 | mao
# Processing Record 4 of Set 7 | yar-sale
# Processing Record 5 of Set 7 | mayumba
# Processing Record 6 of Set 7 | jalu
# Processing Record 7 of Set 7 | karratha
# Processing Record 8 of Set 7 | cajnice
# Processing Record 9 of Set 7 | kungurtug
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | windham
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | bourail
# Processing Record 14 of Set 7 | sinjai
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 7 | show low
# Processing Record 18 of Set 7 | doksy
# Processing Record 19 of Set 7 | axim
# Processing Record 20 of Set 7 | charters towers
# Processing Record 21 of Set 7 | quatre cocos
# Processing Record 22 of Set 7 | chicama
# Processing Record 23 of Set 7 | huaicheng
# Processing Record 24 of Set 7 | nouakchott
# Processing Record 25 of Set 7 | boa vista
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | tokmak
# Processing Record 28 of Set 7 | falavarjan
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | canakkale
# Processing Record 31 of Set 7 | dalvik
# Processing Record 32 of Set 7 | emba
# Processing Record 33 of Set 7 | puerto madryn
# Processing Record 34 of Set 7 | mikhaylovskoye
# Processing Record 35 of Set 7 | brownwood
# Processing Record 36 of Set 7 | demyansk
# Processing Record 37 of Set 7 | shenjiamen
# Processing Record 38 of Set 7 | barcelona
# Processing Record 39 of Set 7 | dunedin
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | berikulskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | kismayo
# Processing Record 44 of Set 7 | westport
# Processing Record 45 of Set 7 | ippy
# Processing Record 46 of Set 7 | mosalsk
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | etne
# Processing Record 49 of Set 7 | imamoglu
# Processing Record 50 of Set 7 | kenai
# Processing Record 1 of Set 8 | altagracia de orituco
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | santa lucia
# Processing Record 4 of Set 8 | paita
# Processing Record 5 of Set 8 | moose factory
# Processing Record 6 of Set 8 | hithadhoo
# Processing Record 7 of Set 8 | morristown
# Processing Record 8 of Set 8 | garowe
# Processing Record 9 of Set 8 | kishtwar
# Processing Record 10 of Set 8 | urumqi
# Processing Record 11 of Set 8 | amapa
# Processing Record 12 of Set 8 | comodoro rivadavia
# Processing Record 13 of Set 8 | wangaratta
# Processing Record 14 of Set 8 | parati
# Processing Record 15 of Set 8 | asau
# Processing Record 16 of Set 8 | souillac
# Processing Record 17 of Set 8 | okahandja
# Processing Record 18 of Set 8 | maguling
# Processing Record 19 of Set 8 | zaozerne
# Processing Record 20 of Set 8 | old town
# Processing Record 21 of Set 8 | kiama
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | alugan
# Processing Record 24 of Set 8 | trhove sviny
# Processing Record 25 of Set 8 | monte santo
# Processing Record 26 of Set 8 | berdigestyakh
# Processing Record 27 of Set 8 | lauro muller
# Processing Record 28 of Set 8 | chimore
# Processing Record 29 of Set 8 | nioro
# Processing Record 30 of Set 8 | abu samrah
# Processing Record 31 of Set 8 | erzin
# Processing Record 32 of Set 8 | kalengwa
# Processing Record 33 of Set 8 | sioux lookout
# Processing Record 34 of Set 8 | alamosa
# Processing Record 35 of Set 8 | lagunas
# Processing Record 36 of Set 8 | buraydah
# Processing Record 37 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 8 | mahibadhoo
# Processing Record 39 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | sabratah
# Processing Record 42 of Set 8 | verkhneyarkeyevo
# Processing Record 43 of Set 8 | coihaique
# Processing Record 44 of Set 8 | dikson
# Processing Record 45 of Set 8 | kysyl-syr
# Processing Record 46 of Set 8 | iwaki
# Processing Record 47 of Set 8 | ust-kuyga
# Processing Record 48 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 8 | bani walid
# Processing Record 50 of Set 8 | ribeira grande
# Processing Record 1 of Set 9 | richards bay
# Processing Record 2 of Set 9 | hedaru
# Processing Record 3 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 9 | kudahuvadhoo
# Processing Record 5 of Set 9 | calabozo
# Processing Record 6 of Set 9 | vinh
# Processing Record 7 of Set 9 | tarbes
# Processing Record 8 of Set 9 | ayan
# Processing Record 9 of Set 9 | providencia
# Processing Record 10 of Set 9 | vostok
# Processing Record 11 of Set 9 | batagay-alyta
# Processing Record 12 of Set 9 | manama
# Processing Record 13 of Set 9 | brae
# Processing Record 14 of Set 9 | mahanoro
# Processing Record 15 of Set 9 | narrabri
# Processing Record 16 of Set 9 | karagay
# Processing Record 17 of Set 9 | xichang
# Processing Record 18 of Set 9 | san pedro
# Processing Record 19 of Set 9 | tiksi
# Processing Record 20 of Set 9 | pangoa
# Processing Record 21 of Set 9 | fort-shevchenko
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | harbour breton
# Processing Record 24 of Set 9 | thompson
# Processing Record 25 of Set 9 | hammerfest
# Processing Record 26 of Set 9 | lincoln
# Processing Record 27 of Set 9 | abu kamal
# Processing Record 28 of Set 9 | hit
# Processing Record 29 of Set 9 | ciudad bolivar
# Processing Record 30 of Set 9 | dicabisagan
# Processing Record 31 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | gengenbach
# Processing Record 34 of Set 9 | shimoda
# Processing Record 35 of Set 9 | grand gaube
# Processing Record 36 of Set 9 | winnemucca
# Processing Record 37 of Set 9 | zaysan
# Processing Record 38 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 9 | victoria
# Processing Record 40 of Set 9 | ossora
# Processing Record 41 of Set 9 | wanganui
# Processing Record 42 of Set 9 | alofi
# Processing Record 43 of Set 9 | valparaiso
# Processing Record 44 of Set 9 | beringovskiy
# Processing Record 45 of Set 9 | ylivieska
# Processing Record 46 of Set 9 | arman
# Processing Record 47 of Set 9 | mbeya
# Processing Record 48 of Set 9 | parkes
# Processing Record 49 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 50 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 10 | kayerkan
# Processing Record 2 of Set 10 | zhangjiakou
# Processing Record 3 of Set 10 | asfi
# Processing Record 4 of Set 10 | touros
# Processing Record 5 of Set 10 | walvis bay
# Processing Record 6 of Set 10 | madaripur
# Processing Record 7 of Set 10 | wanning
# Processing Record 8 of Set 10 | pahrump
# Processing Record 9 of Set 10 | awbari
# Processing Record 10 of Set 10 | masumbwe
# Processing Record 11 of Set 10 | cabanas
# Processing Record 12 of Set 10 | marsh harbour
# Processing Record 13 of Set 10 | seoul
# Processing Record 14 of Set 10 | kampot
# Processing Record 15 of Set 10 | general roca
# Processing Record 16 of Set 10 | nicolas bravo
# Processing Record 17 of Set 10 | kamaishi
# Processing Record 18 of Set 10 | fort saint james
# Processing Record 19 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 10 | dingle
# Processing Record 21 of Set 10 | puerto ayacucho
# Processing Record 22 of Set 10 | mareeba
# Processing Record 23 of Set 10 | launceston
# Processing Record 24 of Set 10 | el badari
# City not found. Skipping...
# Processing Record 25 of Set 10 | texas city
# Processing Record 26 of Set 10 | labuhan
# Processing Record 27 of Set 10 | tubuala
# Processing Record 28 of Set 10 | altus
# Processing Record 29 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 10 | sivaki
# Processing Record 31 of Set 10 | progreso
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | san joaquin
# Processing Record 34 of Set 10 | pevek
# Processing Record 35 of Set 10 | kichmengskiy gorodok
# Processing Record 36 of Set 10 | kalmanka
# Processing Record 37 of Set 10 | mandalgovi
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | ust-koksa
# Processing Record 40 of Set 10 | nouadhibou
# Processing Record 41 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 10 | palaikastron
# Processing Record 43 of Set 10 | erbaa
# Processing Record 44 of Set 10 | anchorage
# Processing Record 45 of Set 10 | antofagasta
# Processing Record 46 of Set 10 | atambua
# Processing Record 47 of Set 10 | qaracala
# Processing Record 48 of Set 10 | tamiahua
# Processing Record 49 of Set 10 | hervey bay
# Processing Record 50 of Set 10 | yulara
# Processing Record 1 of Set 11 | ust-nera
# Processing Record 2 of Set 11 | leningradskiy
# Processing Record 3 of Set 11 | plakhtiyivka
# Processing Record 4 of Set 11 | presidente medici
# Processing Record 5 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 11 | tanta
# Processing Record 7 of Set 11 | porto novo
# Processing Record 8 of Set 11 | terrace
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | mulki
# Processing Record 11 of Set 11 | kholodnyy
# Processing Record 12 of Set 11 | palu
# Processing Record 13 of Set 11 | agadez
# Processing Record 14 of Set 11 | mopti
# Processing Record 15 of Set 11 | yablonovo
# Processing Record 16 of Set 11 | hamilton
# Processing Record 17 of Set 11 | manaure
# Processing Record 18 of Set 11 | port ellen
# City not found. Skipping...
# Processing Record 19 of Set 11 | skelleftea
# Processing Record 20 of Set 11 | bambanglipuro
# Processing Record 21 of Set 11 | kununurra
# Processing Record 22 of Set 11 | montague
# Processing Record 23 of Set 11 | moussoro
# Processing Record 24 of Set 11 | pietersburg
# Processing Record 25 of Set 11 | mildura
# Processing Record 26 of Set 11 | dalbandin
# Processing Record 27 of Set 11 | pak phanang
# Processing Record 28 of Set 11 | mount isa
# Processing Record 29 of Set 11 | mangrol
# Processing Record 30 of Set 11 | bukachacha
# Processing Record 31 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 11 | russell
# Processing Record 33 of Set 11 | kyaukse
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | pingliang
# Processing Record 36 of Set 11 | mantua
# Processing Record 37 of Set 11 | wanaka
# Processing Record 38 of Set 11 | liepaja
# Processing Record 39 of Set 11 | alpena
# Processing Record 40 of Set 11 | valle de banderas
# Processing Record 41 of Set 11 | bagdarin
# Processing Record 42 of Set 11 | bay roberts
# Processing Record 43 of Set 11 | healdsburg
# Processing Record 44 of Set 11 | nicoya
# Processing Record 45 of Set 11 | mayo
# Processing Record 46 of Set 11 | florida
# Processing Record 47 of Set 11 | puerto penasco
# Processing Record 48 of Set 11 | ruteng
# Processing Record 49 of Set 11 | port keats
# Processing Record 50 of Set 11 | fare
# Processing Record 1 of Set 12 | bajil
# Processing Record 2 of Set 12 | boda
# Processing Record 3 of Set 12 | agadir
# Processing Record 4 of Set 12 | rio gallegos
# Processing Record 5 of Set 12 | truth or consequences
# Processing Record 6 of Set 12 | acapulco
# Processing Record 7 of Set 12 | brewster
# Processing Record 8 of Set 12 | amarillo
# Processing Record 9 of Set 12 | newport
# Processing Record 10 of Set 12 | muli
# Processing Record 11 of Set 12 | kazachinskoye
# Processing Record 12 of Set 12 | yeehaw junction
# City not found. Skipping...
# Processing Record 13 of Set 12 | bayan
# Processing Record 14 of Set 12 | chirongui
# Processing Record 15 of Set 12 | sinazongwe
# Processing Record 16 of Set 12 | japura
# Processing Record 17 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 18 of Set 12 | beloha
# Processing Record 19 of Set 12 | santa maria
# Processing Record 20 of Set 12 | lyubar
# Processing Record 21 of Set 12 | boo
# Processing Record 22 of Set 12 | apatou
# Processing Record 23 of Set 12 | albury
# Processing Record 24 of Set 12 | zmeinogorsk
# Processing Record 25 of Set 12 | bosaso
# Processing Record 26 of Set 12 | luau
# Processing Record 27 of Set 12 | koungheul
# Processing Record 28 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 12 | nyurba
# Processing Record 30 of Set 12 | talcahuano
# Processing Record 31 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 12 | alice springs
# Processing Record 33 of Set 12 | acarau
# Processing Record 34 of Set 12 | mount barker
# Processing Record 35 of Set 12 | mangai
# Processing Record 36 of Set 12 | montlucon
# Processing Record 37 of Set 12 | coahuayana
# Processing Record 38 of Set 12 | pingzhuang
# Processing Record 39 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 12 | jacksonville
# Processing Record 41 of Set 12 | oskaloosa
# Processing Record 42 of Set 12 | nome
# Processing Record 43 of Set 12 | sobolevo
# Processing Record 44 of Set 12 | manakara
# Processing Record 45 of Set 12 | laguna
# Processing Record 46 of Set 12 | bow island
# Processing Record 47 of Set 12 | young
# Processing Record 48 of Set 12 | medicine hat
# Processing Record 49 of Set 12 | black forest
# Processing Record 50 of Set 12 | roswell
# Processing Record 1 of Set 13 | abay
# Processing Record 2 of Set 13 | liniere
# City not found. Skipping...
# Processing Record 3 of Set 13 | poum
# Processing Record 4 of Set 13 | mbini
# Processing Record 5 of Set 13 | flin flon
# Processing Record 6 of Set 13 | nynashamn
# Processing Record 7 of Set 13 | nestorion
# City not found. Skipping...
# Processing Record 8 of Set 13 | henties bay
# Processing Record 9 of Set 13 | sur
# Processing Record 10 of Set 13 | rabat
# Processing Record 11 of Set 13 | thunder bay
# Processing Record 12 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | waingapu
# Processing Record 14 of Set 13 | saint anthony
# Processing Record 15 of Set 13 | cadca
# Processing Record 16 of Set 13 | conde
# Processing Record 17 of Set 13 | baneh
# Processing Record 18 of Set 13 | port hueneme
# Processing Record 19 of Set 13 | san quintin
# Processing Record 20 of Set 13 | malavalli
# Processing Record 21 of Set 13 | sitka
# Processing Record 22 of Set 13 | nayoro
# Processing Record 23 of Set 13 | minudasht
# Processing Record 24 of Set 13 | rocha
# Processing Record 25 of Set 13 | santarem
# Processing Record 26 of Set 13 | kholtoson
# Processing Record 27 of Set 13 | novoorsk
# Processing Record 28 of Set 13 | gawler
# Processing Record 29 of Set 13 | chumikan
# Processing Record 30 of Set 13 | velyka bahachka
# Processing Record 31 of Set 13 | hoa binh
# Processing Record 32 of Set 13 | mehamn
# Processing Record 33 of Set 13 | varhaug
# Processing Record 34 of Set 13 | puli
# Processing Record 35 of Set 13 | archidona
# Processing Record 36 of Set 13 | raudeberg
# Processing Record 37 of Set 13 | talnakh
# Processing Record 38 of Set 13 | san carlos de bariloche
# Processing Record 39 of Set 13 | sooke
# Processing Record 40 of Set 13 | yuli
# Processing Record 41 of Set 13 | marienburg
# Processing Record 42 of Set 13 | lashio
# Processing Record 43 of Set 13 | golden
# Processing Record 44 of Set 13 | turukhansk
# Processing Record 45 of Set 13 | warragul
# Processing Record 46 of Set 13 | deer lake
# Processing Record 47 of Set 13 | balabac
# Processing Record 48 of Set 13 | putina
# Processing Record 49 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 13 | tezu
# Processing Record 1 of Set 14 | zharkent
# Processing Record 2 of Set 14 | palmas
# Processing Record 3 of Set 14 | sabang
# Processing Record 4 of Set 14 | bafra
# Processing Record 5 of Set 14 | ayer itam
# City not found. Skipping...
# Processing Record 6 of Set 14 | andra
# Processing Record 7 of Set 14 | mamallapuram
# Processing Record 8 of Set 14 | smithers
# Processing Record 9 of Set 14 | leh
# Processing Record 10 of Set 14 | shingu
# Processing Record 11 of Set 14 | mafinga
# Processing Record 12 of Set 14 | kangaatsiaq
# Processing Record 13 of Set 14 | ureki
# Processing Record 14 of Set 14 | yinchuan
# Processing Record 15 of Set 14 | bozhou
# Processing Record 16 of Set 14 | buala
# Processing Record 17 of Set 14 | gualaquiza
# Processing Record 18 of Set 14 | beawar
# Processing Record 19 of Set 14 | yumen
# Processing Record 20 of Set 14 | taltal
# Processing Record 21 of Set 14 | mawlaik
# Processing Record 22 of Set 14 | jeremie
# Processing Record 23 of Set 14 | vasto
# Processing Record 24 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 14 | klyuchi
# Processing Record 26 of Set 14 | calvinia
# Processing Record 27 of Set 14 | gurupi
# Processing Record 28 of Set 14 | wexford
# Processing Record 29 of Set 14 | fairbanks
# Processing Record 30 of Set 14 | kristinehamn
# Processing Record 31 of Set 14 | la ronge
# Processing Record 32 of Set 14 | ambovombe
# Processing Record 33 of Set 14 | a
# City not found. Skipping...
# Processing Record 34 of Set 14 | sabya
# Processing Record 35 of Set 14 | deputatskiy
# Processing Record 36 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 37 of Set 14 | nyimba
# Processing Record 38 of Set 14 | port lincoln
# Processing Record 39 of Set 14 | innerleithen
# Processing Record 40 of Set 14 | hobyo
# Processing Record 41 of Set 14 | yulin
# Processing Record 42 of Set 14 | singapore
# Processing Record 43 of Set 14 | havre-saint-pierre
# Processing Record 44 of Set 14 | salaberry-de-valleyfield
# Processing Record 45 of Set 14 | oranjemund
# Processing Record 46 of Set 14 | muzhi
# Processing Record 47 of Set 14 | leua
# Processing Record 48 of Set 14 | christchurch
# Processing Record 49 of Set 14 | tyumentsevo
# Processing Record 50 of Set 14 | vaitape
# Processing Record 1 of Set 15 | caxito
# Processing Record 2 of Set 15 | yongan
# Processing Record 3 of Set 15 | pedernales
# Processing Record 4 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 15 | vanimo
# Processing Record 6 of Set 15 | stornoway
# Processing Record 7 of Set 15 | karabulak
# Processing Record 8 of Set 15 | york
# Processing Record 9 of Set 15 | baykit
# Processing Record 10 of Set 15 | inndyr
# Processing Record 11 of Set 15 | bairnsdale
# Processing Record 12 of Set 15 | velykoploske
# Processing Record 13 of Set 15 | tiznit
# Processing Record 14 of Set 15 | macas
# Processing Record 15 of Set 15 | ponta delgada
# Processing Record 16 of Set 15 | elliot
# Processing Record 17 of Set 15 | kinshasa
# Processing Record 18 of Set 15 | dawson creek
# Processing Record 19 of Set 15 | empalme
# Processing Record 20 of Set 15 | prince rupert
# Processing Record 21 of Set 15 | omboue
# Processing Record 22 of Set 15 | sugod
# Processing Record 23 of Set 15 | ormara
# Processing Record 24 of Set 15 | pemangkat
# Processing Record 25 of Set 15 | fort dodge
# Processing Record 26 of Set 15 | bairiki
# Processing Record 27 of Set 15 | biak
# Processing Record 28 of Set 15 | maxixe
# Processing Record 29 of Set 15 | sumkino
# Processing Record 30 of Set 15 | frontera
# Processing Record 31 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 32 of Set 15 | villa guerrero
# Processing Record 33 of Set 15 | singaparna
# Processing Record 34 of Set 15 | najran
# Processing Record 35 of Set 15 | altamira
# Processing Record 36 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 15 | loding
# Processing Record 38 of Set 15 | viransehir
# Processing Record 39 of Set 15 | correia pinto
# Processing Record 40 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 41 of Set 15 | lazaro cardenas
# Processing Record 42 of Set 15 | ushtobe
# Processing Record 43 of Set 15 | portland
# Processing Record 44 of Set 15 | zvolen
# Processing Record 45 of Set 15 | almeirim
# Processing Record 46 of Set 15 | makakilo city
# Processing Record 47 of Set 15 | washington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vaini      TO -21.2000 -175.2000     78.96        73          20
# 1    Rikitea      PF -23.1203 -134.9692     75.49        74          93
# 2  Busselton      AU -33.6500  115.3333     50.04        66          47
# 3    Ushuaia      AR -54.8000  -68.3000     28.06       100          90
# 4    Qaanaaq      GL  77.4840  -69.3632     34.11        79          26
#
#    Wind Speed Current Description
# 0       10.36          few clouds
# 1       19.33     overcast clouds
# 2       14.65    scattered clouds
# 3       18.41          light snow
# 4        2.57    scattered clouds

# %%
# Creating the output file (CSV)
output_data_file = "weather_database/WeatherPy_Database.csv"

# Exporting the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
